# %% [markdown]
# <h1>Dados Covid-19 - Análise Exploratória</h1>

# %% [markdown]
# Dados obtidos do site <a href="https://brasil.io">Brasil.io</a>. O qual disponibiliza não apenas os dados como também documentação, diversas visualizações dos dados, uma API de acesso além do código fonte de tudo.
#
# URL direta dos dados: <a href="https://brasil.io/dataset/covid19/files/">https://brasil.io/dataset/covid19/files/</a>.
#
# Data de download: 02/03/2021

# %% [markdown]
# <h2>Análise Exploratória</h2>
# Tentar obter o máximo de informações do conjunto de dados.

# %% [markdown]
# Carga da biblioteca gráfica:

# %%
library("ggplot2")

# %% [markdown]
# Carga dos dados.

# %%
dados <- read.csv("../input/covid19/caso.csv", header = TRUE, stringsAsFactors = FALSE)

# %% [markdown]
# Os dados já vem com um cabeçalho, o que ajuda muito!
# No github referente ao site <a href="https://brasil.io">Brasil.io</a>, existe documentação relacionada aos dados, a qual reproduzo logo abaixo. A documentação original pode ser acessada clicando <a href="https://github.com/turicas/covid19-br/blob/master/api.md#casos">aqui</a>.
# Colunas:
# <ul>
# <li>date: data de coleta dos dados no formato YYYY-MM-DD.</li>
# <li>state: sigla da unidade federativa, exemplo: SP.</li>
# <li>city: nome do município (pode estar em branco quando o registro é referente ao estado, pode ser preenchido com Importados/Indefinidos também).</li>
# <li>place_type: tipo de local que esse registro descreve, pode ser city ou state.</li>
# <li>order_for_place: número que identifica a ordem do registro para este local. O registro referente ao primeiro boletim em que esse local aparecer será contabilizado como 1 e os demais boletins incrementarão esse valor.</li>
# <li>is_last: campo pré-computado que diz se esse registro é o mais novo para esse local, pode ser True ou False (caso filtre por esse campo, use is_last=True ou is_last=False, não use o valor em minúsculas).</li>
# <li>city_ibge_code: código IBGE do local.</li>
# <li>confirmed: número de casos confirmados.</li>
# <li>deaths: número de mortes.</li>
# <li>estimated_population: população estimada para esse município/estado em 2020, segundo o IBGE. (acesse o script que faz o download e conversão dos dados de população).</li>
# <li>estimated_population_2019: população estimada para esse município/estado em 2019, segundo o IBGE. ATENÇÃO: essa coluna possui valores desatualizados, prefira usar a coluna estimated_population.</li>
# <li>confirmed_per_100k_inhabitants: número de casos confirmados por 100.000 habitantes (baseado em estimated_population).</li>
# <li>death_rate: taxa de mortalidade (mortes / confirmados).</li>
# </ul>
# Ainda assim, vamos fazer uma análise exploratória:

# %% [markdown]
# Qual o tamanho do conjunto de dados?

# %%
dim(dados)
# Out:
# [1] 1616759      13

# %% [markdown]
# Vejamos algumas linhas das informações que ele traz.

# %%
head(dados)
# Out:
#   date       state city place_type confirmed deaths order_for_place is_last
# 1 2021-03-15 AC         state      62940     1129   364             True
# 2 2021-03-14 AC         state      62620     1122   363             False
# 3 2021-03-13 AC         state      62332     1116   362             False
# 4 2021-03-12 AC         state      61709     1106   361             False
# 5 2021-03-11 AC         state      61394     1094   360             False
# 6 2021-03-10 AC         state      61121     1083   359             False
#   estimated_population_2019 estimated_population city_ibge_code
# 1 881935                    894470               12
# 2 881935                    894470               12
# 3 881935                    894470               12
# 4 881935                    894470               12
# 5 881935                    894470               12
# 6 881935                    894470               12
#   confirmed_per_100k_inhabitants death_rate
# 1 7036.569                       0.0179
# 2 7000.794                       0.0179
# 3 6968.596                       0.0179
# 4 6898.946                       0.0179
# 5 6863.729                       0.0178
# 6 6833.208                       0.0177

# %%
tail(dados)
# Out:
#         date       state city place_type confirmed deaths order_for_place
# 1616754 2020-06-24 SP    Óleo city       1         0      6
# 1616755 2020-06-23 SP    Óleo city       1         0      5
# 1616756 2020-06-22 SP    Óleo city       1         0      4
# 1616757 2020-06-21 SP    Óleo city       1         0      3
# 1616758 2020-06-20 SP    Óleo city       1         0      2
# 1616759 2020-06-19 SP    Óleo city       1         0      1
#         is_last estimated_population_2019 estimated_population city_ibge_code
# 1616754 False   2496                      2471                 3533809
# 1616755 False   2496                      2471                 3533809
# 1616756 False   2496                      2471                 3533809
# 1616757 False   2496                      2471                 3533809
# 1616758 False   2496                      2471                 3533809
# 1616759 False   2496                      2471                 3533809
#         confirmed_per_100k_inhabitants death_rate
# 1616754 40.46945                       0
# 1616755 40.46945                       0
# 1616756 40.46945                       0
# 1616757 40.46945                       0
# 1616758 40.46945                       0
# 1616759 40.46945                       0

# %% [markdown]
# Informações básicas sobre os atributos do conjunto de dados:

# %%
str(dados)
# Out:
# 'data.frame':	1616759 obs. of  13 variables:
#  $ date                          : chr  "2021-03-15" "2021-03-14" "2021-03-13" "2021-03-12" ...
#  $ state                         : chr  "AC" "AC" "AC" "AC" ...
#  $ city                          : chr  "" "" "" "" ...
#  $ place_type                    : chr  "state" "state" "state" "state" ...
#  $ confirmed                     : int  62940 62620 62332 61709 61394 61121 60721 60656 60288 60070 ...
#  $ deaths                        : int  1129 1122 1116 1106 1094 1083 1071 1066 1063 1054 ...
#  $ order_for_place               : int  364 363 362 361 360 359 358 357 356 355 ...
#  $ is_last                       : chr  "True" "False" "False" "False" ...
#  $ estimated_population_2019     : int  881935 881935 881935 881935 881935 881935 881935 881935 881935 881935 ...
#  $ estimated_population          : int  894470 894470 894470 894470 894470 894470 894470 894470 894470 894470 ...
#  $ city_ibge_code                : int  12 12 12 12 12 12 12 12 12 12 ...
#  $ confirmed_per_100k_inhabitants: num  7037 7001 6969 6899 6864 ...
#  $ death_rate                    : num  0.0179 0.0179 0.0179 0.0179 0.0178 0.0177 0.0176 0.0176 0.0176 0.0175 ...

# %% [markdown]
# Que atributos possui?

# %%
names(dados)
# Out:
#  [1] "date"                           "state"
#  [3] "city"                           "place_type"
#  [5] "confirmed"                      "deaths"
#  [7] "order_for_place"                "is_last"
#  [9] "estimated_population_2019"      "estimated_population"
# [11] "city_ibge_code"                 "confirmed_per_100k_inhabitants"
# [13] "death_rate"

# %% [markdown]
# Sumarizando os dados temos informações mais detalhadas sobre cada um dos atributos:
# <ul>
#     <li><i>city</i> possui 9453 registros com este atributo vazio (são dados dos estados) e 5774 registros com o valor <i>Importados/Indefinidos</i>.</li>
#     <li><i>confirmed</i> e <i>deaths</i> possuem valores baixos (amém), com mediana baixa, média maior (possívelmente puxada para cima por conta do valor máximo).</li>
#     <li>As colunas de população estimada <i>estimated_population</i> e a coluna <i>city_ibge_code</i> possuem o mesmo número de valores <i>NA</i> (not available). Isso acaba refletindo na coluna <i>confirmed_per_100k_inhabitants</i>. Os <i>NA</i> devem ser para cidades novas, que não apareciam no censo do IBGE e também para os <i>Importados/Indefinidos</i> da coluna <i>city</i>.</li>
#     <li>Os dados fazem sentido. Os campos <i>confirmed</i>, <i>deaths</i>, <i>estimated_population_2019</i>, <i>estimated_population</i>, <i>confirmed_per_100k_inhabitants</i> e <i>death_rate</i> tem valores maiores ou iguais a zero (afora os <i>NA</i>)</li>
# </ul>

# %%
summary(dados)
# Out:
#      date              state               city            place_type
#  Length:1616759     Length:1616759     Length:1616759     Length:1616759
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#    confirmed           deaths         order_for_place   is_last
#  Min.   :      0   Min.   :    0.00   Min.   :  1.0   Length:1616759
#  1st Qu.:     31   1st Qu.:    0.00   1st Qu.: 72.0   Class :character
#  Median :    139   Median :    3.00   Median :144.0   Mode  :character
#  Mean   :   1891   Mean   :   52.69   Mean   :147.4
#  3rd Qu.:    495   3rd Qu.:   10.00   3rd Qu.:218.0
#  Max.   :2208242   Max.   :64223.00   Max.   :378.0
#
#  estimated_population_2019 estimated_population city_ibge_code
#  Min.   :     781          Min.   :     776     Min.   :     11
#  1st Qu.:    5874          1st Qu.:    5900     1st Qu.:2505808
#  Median :   12908          Median :   12948     Median :3142809
#  Mean   :   90640          Mean   :   91340     Mean   :3204887
#  3rd Qu.:   28496          3rd Qu.:   28684     3rd Qu.:4115408
#  Max.   :45919049          Max.   :46289333     Max.   :5300108
#  NA's   :6005              NA's   :6005         NA's   :6005
#  confirmed_per_100k_inhabitants   death_rate
#  Min.   :    0.0                Min.   :0.00000
#  1st Qu.:  366.4                1st Qu.:0.00000
#  Median : 1333.1                Median :0.01670
#  Mean   : 1992.5                Mean   :0.03024
#  3rd Qu.: 2866.4                3rd Qu.:0.03130
#  Max.   :34118.2                Max.   :1.00000
#  NA's   :20094

# %% [markdown]
# Vamos manter apenas os dados dos municípios do estado do Rio de Janeiro e vamos remover colunas que não serão utilizadas: <i>state</i> (é sempre <i>RJ</i>), <i>place_type</i> (é sempre <i>city</i>) e <i>estimated_population_2019</i> (desatualizada)

# %%
dados <- dados[dados$state == "RJ" & dados$place_type == "city", ]
dados <- dados[ , - c(2, 4, 9)] # state, place_type, estimated_population_2019

# %% [markdown]
# Existem NAs?

# %%
any(is.na(dados))
# Out:
# [1] TRUE

# %% [markdown]
# Em que coluna?

# %%
colSums(is.na(dados))
# Out:
#                           date                           city
#                              0                              0
#                      confirmed                         deaths
#                              0                              0
#                order_for_place                        is_last
#                              0                              0
#           estimated_population                 city_ibge_code
#                            355                            355
# confirmed_per_100k_inhabitants                     death_rate
#                            434                              0

# %% [markdown]
# Vamos ver:

# %%
dados[is.na(dados$estimated_population), ]
# Out:
#        date       city                   confirmed deaths order_for_place
# 808042 2021-03-14 Importados/Indefinidos 0         0      355
# 808043 2021-03-13 Importados/Indefinidos 0         0      354
# 808044 2021-03-12 Importados/Indefinidos 0         0      353
# 808045 2021-03-11 Importados/Indefinidos 0         0      352
# 808046 2021-03-10 Importados/Indefinidos 0         0      351
# 808047 2021-03-09 Importados/Indefinidos 0         0      350
# 808048 2021-03-08 Importados/Indefinidos 0         0      349
# 808049 2021-03-07 Importados/Indefinidos 0         0      348
# 808050 2021-03-06 Importados/Indefinidos 0         0      347
# 808051 2021-03-05 Importados/Indefinidos 0         0      346
# 808052 2021-03-04 Importados/Indefinidos 0         0      345
# 808053 2021-03-03 Importados/Indefinidos 0         0      344
# 808054 2021-03-02 Importados/Indefinidos 0         0      343
# 808055 2021-03-01 Importados/Indefinidos 0         0      342
# 808056 2021-02-28 Importados/Indefinidos 0         0      341
# 808057 2021-02-27 Importados/Indefinidos 0         0      340
# 808058 2021-02-26 Importados/Indefinidos 0         0      339
# 808059 2021-02-25 Importados/Indefinidos 0         0      338
# 808060 2021-02-24 Importados/Indefinidos 0         0      337
# 808061 2021-02-23 Importados/Indefinidos 0         0      336
# 808062 2021-02-22 Importados/Indefinidos 0         0      335
# 808063 2021-02-21 Importados/Indefinidos 0         0      334
# 808064 2021-02-20 Importados/Indefinidos 0         0      333
# 808065 2021-02-19 Importados/Indefinidos 0         0      332
# 808066 2021-02-18 Importados/Indefinidos 0         0      331
# 808067 2021-02-17 Importados/Indefinidos 0         0      330
# 808068 2021-02-16 Importados/Indefinidos 0         0      329
# 808069 2021-02-15 Importados/Indefinidos 0         0      328
# 808070 2021-02-14 Importados/Indefinidos 0         0      327
# 808071 2021-02-13 Importados/Indefinidos 0         0      326
# ⋮      ⋮          ⋮                      ⋮         ⋮      ⋮
# 808367 2020-04-19 Importados/Indefinidos 0         0      30
# 808368 2020-04-18 Importados/Indefinidos 1         0      29
# 808369 2020-04-17 Importados/Indefinidos 1         0      28
# 808370 2020-04-16 Importados/Indefinidos 1         0      27
# 808371 2020-04-15 Importados/Indefinidos 1         0      26
# 808372 2020-04-14 Importados/Indefinidos 1         0      25
# 808373 2020-04-13 Importados/Indefinidos 1         0      24
# 808374 2020-04-12 Importados/Indefinidos 1         0      23
# 808375 2020-04-11 Importados/Indefinidos 1         0      22
# 808376 2020-04-10 Importados/Indefinidos 1         0      21
# 808377 2020-04-09 Importados/Indefinidos 1         0      20
# 808378 2020-04-08 Importados/Indefinidos 1         0      19
# 808379 2020-04-07 Importados/Indefinidos 1         0      18
# 808380 2020-04-06 Importados/Indefinidos 1         0      17
# 808381 2020-04-05 Importados/Indefinidos 1         0      16
# 808382 2020-04-04 Importados/Indefinidos 1         0      15
# 808383 2020-04-03 Importados/Indefinidos 1         0      14
# 808384 2020-04-02 Importados/Indefinidos 7         0      13
# 808385 2020-04-01 Importados/Indefinidos 0         0      12
# 808386 2020-03-31 Importados/Indefinidos 0         0      11
# 808387 2020-03-30 Importados/Indefinidos 0         0      10
# 808388 2020-03-29 Importados/Indefinidos 0         0       9
# 808389 2020-03-28 Importados/Indefinidos 0         0       8
# 808390 2020-03-27 Importados/Indefinidos 0         0       7
# 808391 2020-03-26 Importados/Indefinidos 0         0       6
# 808392 2020-03-25 Importados/Indefinidos 0         0       5
# 808393 2020-03-24 Importados/Indefinidos 2         0       4
# 808394 2020-03-23 Importados/Indefinidos 2         0       3
# 808395 2020-03-22 Importados/Indefinidos 2         0       2
# 808396 2020-03-21 Importados/Indefinidos 4         0       1
#        is_last estimated_population city_ibge_code
# 808042 True    NA                   NA
# 808043 False   NA                   NA
# 808044 False   NA                   NA
# 808045 False   NA                   NA
# 808046 False   NA                   NA
# 808047 False   NA                   NA
# 808048 False   NA                   NA
# 808049 False   NA                   NA
# 808050 False   NA                   NA
# 808051 False   NA                   NA
# 808052 False   NA                   NA
# 808053 False   NA                   NA
# 808054 False   NA                   NA
# 808055 False   NA                   NA
# 808056 False   NA                   NA
# 808057 False   NA                   NA
# 808058 False   NA                   NA
# 808059 False   NA                   NA
# 808060 False   NA                   NA
# 808061 False   NA                   NA
# 808062 False   NA                   NA
# 808063 False   NA                   NA
# 808064 False   NA                   NA
# 808065 False   NA                   NA
# 808066 False   NA                   NA
# 808067 False   NA                   NA
# 808068 False   NA                   NA
# 808069 False   NA                   NA
# 808070 False   NA                   NA
# 808071 False   NA                   NA
# ⋮      ⋮       ⋮                    ⋮
# 808367 False   NA                   NA
# 808368 False   NA                   NA
# 808369 False   NA                   NA
# 808370 False   NA                   NA
# 808371 False   NA                   NA
# 808372 False   NA                   NA
# 808373 False   NA                   NA
# 808374 False   NA                   NA
# 808375 False   NA                   NA
# 808376 False   NA                   NA
# 808377 False   NA                   NA
# 808378 False   NA                   NA
# 808379 False   NA                   NA
# 808380 False   NA                   NA
# 808381 False   NA                   NA
# 808382 False   NA                   NA
# 808383 False   NA                   NA
# 808384 False   NA                   NA
# 808385 False   NA                   NA
# 808386 False   NA                   NA
# 808387 False   NA                   NA
# 808388 False   NA                   NA
# 808389 False   NA                   NA
# 808390 False   NA                   NA
# 808391 False   NA                   NA
# 808392 False   NA                   NA
# 808393 False   NA                   NA
# 808394 False   NA                   NA
# 808395 False   NA                   NA
# 808396 False   NA                   NA
#        confirmed_per_100k_inhabitants death_rate
# 808042 NA                             0
# 808043 NA                             0
# 808044 NA                             0
# 808045 NA                             0
# 808046 NA                             0
# 808047 NA                             0
# 808048 NA                             0
# 808049 NA                             0
# 808050 NA                             0
# 808051 NA                             0
# 808052 NA                             0
# 808053 NA                             0
# 808054 NA                             0
# 808055 NA                             0
# 808056 NA                             0
# 808057 NA                             0
# 808058 NA                             0
# 808059 NA                             0
# 808060 NA                             0
# 808061 NA                             0
# 808062 NA                             0
# 808063 NA                             0
# 808064 NA                             0
# 808065 NA                             0
# 808066 NA                             0
# 808067 NA                             0
# 808068 NA                             0
# 808069 NA                             0
# 808070 NA                             0
# 808071 NA                             0
# ⋮      ⋮                              ⋮
# 808367 NA                             0
# 808368 NA                             0
# 808369 NA                             0
# 808370 NA                             0
# 808371 NA                             0
# 808372 NA                             0
# 808373 NA                             0
# 808374 NA                             0
# 808375 NA                             0
# 808376 NA                             0
# 808377 NA                             0
# 808378 NA                             0
# 808379 NA                             0
# 808380 NA                             0
# 808381 NA                             0
# 808382 NA                             0
# 808383 NA                             0
# 808384 NA                             0
# 808385 NA                             0
# 808386 NA                             0
# 808387 NA                             0
# 808388 NA                             0
# 808389 NA                             0
# 808390 NA                             0
# 808391 NA                             0
# 808392 NA                             0
# 808393 NA                             0
# 808394 NA                             0
# 808395 NA                             0
# 808396 NA                             0

# %% [markdown]
# Ah, esqueci de retirar os <i>Importados/Indefinidos</i>:

# %%
dados <- dados[dados$city != "Importados/Indefinidos", ]

# %% [markdown]
# Ainda existem NAs?

# %%
any(is.na(dados))
# Out:
# [1] TRUE

# %% [markdown]
# Que chato! Em que coluna?

# %%
colSums(is.na(dados))
# Out:
#                           date                           city
#                              0                              0
#                      confirmed                         deaths
#                              0                              0
#                order_for_place                        is_last
#                              0                              0
#           estimated_population                 city_ibge_code
#                              0                              0
# confirmed_per_100k_inhabitants                     death_rate
#                             79                              0

# %% [markdown]
# Vamos dar uma olhada:

# %%
dados[is.na(dados$confirmed_per_100k_inhabitants), ]
# Out:
#        date       city              confirmed deaths order_for_place is_last
# 809403 2020-04-30 Italva            0         0       4              False
# 809404 2020-04-29 Italva            0         0       3              False
# 809405 2020-04-28 Italva            0         0       2              False
# 811690 2020-05-07 Macuco            0         0      15              False
# 811691 2020-05-06 Macuco            0         0      14              False
# 811692 2020-05-05 Macuco            0         0      13              False
# 811693 2020-05-04 Macuco            0         0      12              False
# 811694 2020-05-03 Macuco            0         0      11              False
# 811695 2020-05-02 Macuco            0         0      10              False
# 811696 2020-05-01 Macuco            0         0       9              False
# 811697 2020-04-30 Macuco            0         0       8              False
# 811698 2020-04-29 Macuco            0         0       7              False
# 811699 2020-04-28 Macuco            0         0       6              False
# 811700 2020-04-27 Macuco            0         0       5              False
# 811701 2020-04-26 Macuco            0         0       4              False
# 811702 2020-04-25 Macuco            0         0       3              False
# 811703 2020-04-24 Macuco            0         0       2              False
# 813414 2020-04-03 Mesquita          0         0       2              False
# 820190 2020-03-27 Resende           0         0       3              False
# 823868 2020-04-22 Silva Jardim      0         0       8              False
# 823869 2020-04-21 Silva Jardim      0         0       7              False
# 823870 2020-04-20 Silva Jardim      0         0       6              False
# 824201 2020-04-19 Sumidouro         0         0      11              False
# 828188 2020-06-03 Trajano de Moraes 0         0      60              False
# 828189 2020-06-02 Trajano de Moraes 0         0      59              False
# 828190 2020-06-01 Trajano de Moraes 0         0      58              False
# 828191 2020-05-31 Trajano de Moraes 0         0      57              False
# 828192 2020-05-30 Trajano de Moraes 0         0      56              False
# 828193 2020-05-29 Trajano de Moraes 0         0      55              False
# 828194 2020-05-28 Trajano de Moraes 0         0      54              False
# ⋮      ⋮          ⋮                 ⋮         ⋮      ⋮               ⋮
# 828217 2020-05-05 Trajano de Moraes 0         0      31              False
# 828218 2020-05-04 Trajano de Moraes 0         0      30              False
# 828219 2020-05-03 Trajano de Moraes 0         0      29              False
# 828220 2020-05-02 Trajano de Moraes 0         0      28              False
# 828221 2020-05-01 Trajano de Moraes 0         0      27              False
# 828222 2020-04-30 Trajano de Moraes 0         0      26              False
# 828223 2020-04-29 Trajano de Moraes 0         0      25              False
# 828224 2020-04-28 Trajano de Moraes 0         0      24              False
# 828225 2020-04-27 Trajano de Moraes 0         0      23              False
# 828226 2020-04-26 Trajano de Moraes 0         0      22              False
# 828227 2020-04-25 Trajano de Moraes 0         0      21              False
# 828228 2020-04-24 Trajano de Moraes 0         0      20              False
# 828229 2020-04-23 Trajano de Moraes 0         0      19              False
# 828230 2020-04-22 Trajano de Moraes 0         0      18              False
# 828231 2020-04-21 Trajano de Moraes 0         0      17              False
# 828232 2020-04-20 Trajano de Moraes 0         0      16              False
# 828233 2020-04-19 Trajano de Moraes 0         0      15              False
# 828234 2020-04-18 Trajano de Moraes 0         0      14              False
# 828235 2020-04-17 Trajano de Moraes 0         0      13              False
# 828236 2020-04-16 Trajano de Moraes 0         0      12              False
# 828237 2020-04-15 Trajano de Moraes 0         0      11              False
# 828238 2020-04-14 Trajano de Moraes 0         0      10              False
# 828239 2020-04-13 Trajano de Moraes 0         0       9              False
# 828240 2020-04-12 Trajano de Moraes 0         0       8              False
# 828241 2020-04-11 Trajano de Moraes 0         0       7              False
# 828242 2020-04-10 Trajano de Moraes 0         0       6              False
# 828243 2020-04-09 Trajano de Moraes 0         0       5              False
# 828244 2020-04-08 Trajano de Moraes 0         0       4              False
# 828245 2020-04-07 Trajano de Moraes 0         0       3              False
# 828246 2020-04-06 Trajano de Moraes 0         0       2              False
#        estimated_population city_ibge_code confirmed_per_100k_inhabitants
# 809403  15299               3302056        NA
# 809404  15299               3302056        NA
# 809405  15299               3302056        NA
# 811690   5623               3302452        NA
# 811691   5623               3302452        NA
# 811692   5623               3302452        NA
# 811693   5623               3302452        NA
# 811694   5623               3302452        NA
# 811695   5623               3302452        NA
# 811696   5623               3302452        NA
# 811697   5623               3302452        NA
# 811698   5623               3302452        NA
# 811699   5623               3302452        NA
# 811700   5623               3302452        NA
# 811701   5623               3302452        NA
# 811702   5623               3302452        NA
# 811703   5623               3302452        NA
# 813414 176569               3302858        NA
# 820190 132312               3304201        NA
# 823868  21774               3305604        NA
# 823869  21774               3305604        NA
# 823870  21774               3305604        NA
# 824201  15667               3305703        NA
# 828188  10640               3305901        NA
# 828189  10640               3305901        NA
# 828190  10640               3305901        NA
# 828191  10640               3305901        NA
# 828192  10640               3305901        NA
# 828193  10640               3305901        NA
# 828194  10640               3305901        NA
# ⋮      ⋮                    ⋮              ⋮
# 828217 10640                3305901        NA
# 828218 10640                3305901        NA
# 828219 10640                3305901        NA
# 828220 10640                3305901        NA
# 828221 10640                3305901        NA
# 828222 10640                3305901        NA
# 828223 10640                3305901        NA
# 828224 10640                3305901        NA
# 828225 10640                3305901        NA
# 828226 10640                3305901        NA
# 828227 10640                3305901        NA
# 828228 10640                3305901        NA
# 828229 10640                3305901        NA
# 828230 10640                3305901        NA
# 828231 10640                3305901        NA
# 828232 10640                3305901        NA
# 828233 10640                3305901        NA
# 828234 10640                3305901        NA
# 828235 10640                3305901        NA
# 828236 10640                3305901        NA
# 828237 10640                3305901        NA
# 828238 10640                3305901        NA
# 828239 10640                3305901        NA
# 828240 10640                3305901        NA
# 828241 10640                3305901        NA
# 828242 10640                3305901        NA
# 828243 10640                3305901        NA
# 828244 10640                3305901        NA
# 828245 10640                3305901        NA
# 828246 10640                3305901        NA
#        death_rate
# 809403 0
# 809404 0
# 809405 0
# 811690 0
# 811691 0
# 811692 0
# 811693 0
# 811694 0
# 811695 0
# 811696 0
# 811697 0
# 811698 0
# 811699 0
# 811700 0
# 811701 0
# 811702 0
# 811703 0
# 813414 0
# 820190 0
# 823868 0
# 823869 0
# 823870 0
# 824201 0
# 828188 0
# 828189 0
# 828190 0
# 828191 0
# 828192 0
# 828193 0
# 828194 0
# ⋮      ⋮
# 828217 0
# 828218 0
# 828219 0
# 828220 0
# 828221 0
# 828222 0
# 828223 0
# 828224 0
# 828225 0
# 828226 0
# 828227 0
# 828228 0
# 828229 0
# 828230 0
# 828231 0
# 828232 0
# 828233 0
# 828234 0
# 828235 0
# 828236 0
# 828237 0
# 828238 0
# 828239 0
# 828240 0
# 828241 0
# 828242 0
# 828243 0
# 828244 0
# 828245 0
# 828246 0

# %% [markdown]
# Não parece que isso vai atrapalhar em nada. Ao que parece o atributo <i>confirmed_per_100k_inhabitants</i> ficou com valor <i>NA</i> sempre que <i>confirmed</i> tem o valor 0 (zero). Vamos confirmar:

# %%
nrow(dados[is.na(dados$confirmed_per_100k_inhabitants), ]) == nrow(dados[dados$confirmed == 0, ])
# Out:
# [1] TRUE

# %% [markdown]
# Como estão os dados de cada município?

# %%
table(dados$city)
# Out:
#                Angra dos Reis                       Aperibé
#                           346                           322
#                      Araruama                         Areal
#                           342                           330
#            Armação dos Búzios               Arraial do Cabo
#                           331                           344
#                Barra do Piraí                   Barra Mansa
#                           342                           363
#                  Belford Roxo                    Bom Jardim
#                           350                           338
#       Bom Jesus do Itabapoana                     Cabo Frio
#                           335                           338
#          Cachoeiras de Macacu                       Cambuci
#                           335                           301
#         Campos dos Goytacazes                     Cantagalo
#                           352                           336
#                     Carapebus               Cardoso Moreira
#                           330                           307
#                         Carmo             Casimiro de Abreu
#                           313                           338
#     Comendador Levy Gasparian           Conceição de Macabu
#                           297                           323
#                      Cordeiro                   Duas Barras
#                           319                           288
#               Duque de Caxias   Engenheiro Paulo de Frontin
#                           352                           310
#                    Guapimirim                 Iguaba Grande
#                           357                           342
#                      Itaboraí                       Itaguaí
#                           349                           343
#                        Italva                      Itaocara
#                           318                           314
#                     Itaperuna                      Itatiaia
#                           340                           335
#                        Japeri                Laje do Muriaé
#                           338                           304
#                         Macaé                        Macuco
#                           345                           322
#                          Magé                   Mangaratiba
#                           343                           348
#                        Maricá                        Mendes
#                           347                           330
#                      Mesquita                Miguel Pereira
#                           343                           356
#                      Miracema                    Natividade
#                           315                           307
#                     Nilópolis                       Niterói
#                           342                           360
#                 Nova Friburgo                   Nova Iguaçu
#                           341                           348
#                     Paracambi                Paraíba do Sul
#                           335                           341
#                        Paraty               Paty do Alferes
#                           336                           336
#                    Petrópolis                     Pinheiral
#                           355                           327
#                         Piraí                   Porciúncula
#                           333                           342
#                    Porto Real                        Quatis
#                           338                           338
#                     Queimados                      Quissamã
#                           346                           330
#                       Resende                    Rio Bonito
#                           351                           346
#                     Rio Claro                Rio das Flores
#                           299                           337
#                Rio das Ostras                Rio de Janeiro
#                           347                           362
#          Santa Maria Madalena        Santo Antônio de Pádua
#                           319                           325
#                   São Fidélis   São Francisco de Itabapoana
#                           333                           335
#                   São Gonçalo             São João da Barra
#                           353                           340
#            São João de Meriti               São José de Ubá
#                           346                           319
# São José do Vale do Rio Preto           São Pedro da Aldeia
#                           318                           345
#         São Sebastião do Alto                      Sapucaia
#                           321                           338
#                     Saquarema                    Seropédica
#                           333                           347
#                  Silva Jardim                     Sumidouro
#                           330                           336
#                        Tanguá                   Teresópolis
#                           340                           346
#             Trajano de Moraes                     Três Rios
#                           340                           342
#                       Valença                     Varre-Sai
#                           351                           297
#                     Vassouras                 Volta Redonda
#                           322                           352

# %% [markdown]
# Qual o máximo de mortes e os dados de onde ocorreu?

# %%
dados[dados$deaths == max(dados$deaths), ]
# Out:
#        date       city           confirmed deaths order_for_place is_last
# 821522 2021-03-14 Rio de Janeiro 213488    19380  362             True
#        estimated_population city_ibge_code confirmed_per_100k_inhabitants
# 821522 6747815              3304557        3163.809
#        death_rate
# 821522 0.0908

# %% [markdown]
# Vamos plotar alguns gráficos:

# %%
ggplot(dados, aes(x=date, y=deaths, group=city)) +
  geom_point(aes(color=city)) +
  geom_line(aes(color=city)) +
  labs(x = "data", y = "mortes") +
  theme_minimal()

# %% [markdown]
# Ops! Muita coisa para um só gráfico. Vamos remover a legenda.

# %%
ggplot(dados, aes(x=date, y=deaths, group=city)) +
  geom_point(aes(color=city), show.legend = FALSE) +
  geom_line(aes(color=city), show.legend = FALSE) +
  labs(x = "data", y = "mortes") +
  theme_minimal()

# %% [markdown]
# Ops! Muitos dados para um só gráfico, além disso um município é muito maior que os outros. Vamos diminuir o conjunto, selecionando apenas alguns municípios para poder plotar.

# %%
temp <- dados[dados$city %in% c("Japeri", "Resende", "Itatiaia", "Rio de Janeiro", "Paraty"), ]

ggplot(temp, aes(x=date, y=deaths, group=city)) +
  geom_point(aes(color=city)) +
  geom_line(aes(color=city)) +
  labs(x = "data", y = "mortes") +
  theme_minimal()

# %% [markdown]
# O Rio de Janeiro cresce muito mais que os outros municípios, por ser uma região metropolitana. Assim não dá pra ver os outros. Vamos tirar o Rio de Janeiro por enquanto.

# %%
temp <- dados[dados$city %in% c("Japeri", "Resende", "Itatiaia", "Paraty"), ]

ggplot(temp, aes(x=date, y=deaths, group=city)) +
  geom_point(aes(color=city)) +
  geom_line(aes(color=city)) +
  labs(x = "data", y = "mortes") +
  theme_minimal()

# %% [markdown]
# É importante observar que o gráfico só cresce! O dado de mortes é cumulativo!!! Eu não havia percebido isso até agora!
#
# A data na parte de baixo do gráfico também não ficou boa...[texto do link](https://)
